# %%
import sys,  os
sys.path.insert(0, '../exostriker/lib')
#sys.path.append('../lib/') #RV_mod directory must be in your path
#sys.path.append('../lib/RV_mod/') #RV_mod directory must be in your path
import RV_mod as rv
import gls as gls
import numpy as np
#import glob
import dill
#import os
#from subprocess import PIPE, Popen 
import csv
import time 

import matplotlib.pyplot as plt
from matplotlib import gridspec
import matplotlib as mpl
  
from scipy.stats.stats import pearsonr   
import pathos as ps
import gc
# Out:
# <ipython-input-10-87b9bd01f875>:19: DeprecationWarning: Please use `pearsonr` from the `scipy.stats` namespace, the `scipy.stats.stats` namespace is deprecated.
#   from scipy.stats.stats import pearsonr

# %%
cp ../../exo

# %%
file_pi = open("./GJ581_HARPS.ses", 'rb')
fit = dill.load(file_pi)
file_pi.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-afb91803bbd5> in <module>
# ----> 1 file_pi = open("./GJ581_HARPS.ses", 'rb')
#       2 fit = dill.load(file_pi)
#       3 file_pi.close()
#
# FileNotFoundError: [Errno 2] No such file or directory: './GJ581_HARPS.ses'

# %%
options = {'Pmin':100, 'Pmax': 1000, 'Pstep': 100,
           'Kmin':10, 'Kmax': 1000, 'Kstep': 100, 
           'M0min':0, 'M0max': 180, 'M0step': 90 }


det_rate_results = rv.run_detection_rate(fit,options)
# Out:
# ...
#   0%|          | 0/10 [00:00<?, ?it/s]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
#  50%|█████     | 1/2 [00:00<00:00,  1.01it/s]
#
# 100%|██████████| 2/2 [00:02<00:00,  1.01s/it]
#
#  10%|█         | 1/10 [00:02<00:18,  2.02s/it]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
#  50%|█████     | 1/2 [00:00<00:00,  1.03it/s]
#
# 100%|██████████| 2/2 [00:01<00:00,  1.02it/s]
#
#  20%|██        | 2/10 [00:03<00:16,  2.00s/it]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
#  50%|█████     | 1/2 [00:00<00:00,  1.03it/s]
#
# 100%|██████████| 2/2 [00:02<00:00,  1.00s/it]
#
#  30%|███       | 3/10 [00:05<00:14,  2.00s/it]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
#  50%|█████     | 1/2 [00:00<00:00,  1.02it/s]
#
# 100%|██████████| 2/2 [00:01<00:00,  1.03it/s]
#
#  40%|████      | 4/10 [00:07<00:11,  1.98s/it]
#
#   0%|          | 0/2 [00:00<?, ?it/s]
#
#  50%|█████     | 1/2 [00:00<00:00,  1.05it/s]
#
# 100%|██████████| 2/2 [00:01<00:00,  1.03it/s]
#
# ...

# %%
f = open("Extracted_det_rate_results.pkl","wb")
dill.dump(det_rate_results,f)
f.close()

# %%
ls
# Out:
# Eta_Ceti_py3.ses                     RV_plot_example_time_series.png
# Extracted_det_rate_results.pkl       RV_plot_ph.pdf
# GJ581_HARPS.ses                      RV_plot_ts.pdf
# Make_plots_from_ses.py               RVmod_as_py_lib_auto_fit_example.py
# RV_plot.pdf                          RVmod_as_py_lib_kep_vs_dyn_example.ipynb
# RV_plot_example.pdf                  RVmod_as_py_lib_kep_vs_dyn_example.py
# RV_plot_example_phased_planet_1.png  Untitled.ipynb
# RV_plot_example_phased_planet_2.png  run_scripts_in_servers_NestSamp.py

# %%
ll -h
# Out:
# total 9.6M
# -rw-r--r-- 1 trifonov 2.3M Mar 20 10:04 Eta_Ceti_py3.ses
# -rw-rw-r-- 1 trifonov 4.5M Jul  7 10:17 Extracted_det_rate_results.pkl
# -rw-rw-r-- 1 trifonov 1.7M Jul  6 22:39 GJ581_HARPS.ses
# -rw-r--r-- 1 trifonov  11K Mar 20 10:04 Make_plots_from_ses.py
# -rw-r--r-- 1 trifonov 178K Mar 20 10:04 RV_plot.pdf
# -rw-r--r-- 1 trifonov 183K Mar 20 10:04 RV_plot_example.pdf
# -rw-r--r-- 1 trifonov 102K Mar 20 10:04 RV_plot_example_phased_planet_1.png
# -rw-r--r-- 1 trifonov 103K Mar 20 10:04 RV_plot_example_phased_planet_2.png
# -rw-r--r-- 1 trifonov 196K Mar 20 10:04 RV_plot_example_time_series.png
# -rw-r--r-- 1 trifonov 140K Mar 20 10:04 RV_plot_ph.pdf
# -rw-r--r-- 1 trifonov 156K Mar 20 10:04 RV_plot_ts.pdf
# -rw-r--r-- 1 trifonov 8.2K Mar 20 10:04 RVmod_as_py_lib_auto_fit_example.py
# -rw-r--r-- 1 trifonov  76K Jul  6 22:35 RVmod_as_py_lib_kep_vs_dyn_example.ipynb
# -rw-r--r-- 1 trifonov 9.3K Mar 20 10:04 RVmod_as_py_lib_kep_vs_dyn_example.py
# ...
